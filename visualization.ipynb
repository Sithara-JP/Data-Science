# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dayanandv/Data-Science/main/dataset/Boston_housing.csv")

# %%
import seaborn as sb
sb.displot(df, x = "TAX")

# %%
sb.jointplot(data = d, x = "PRICE", y = "RM", kind = "reg")
sb.regplot(x = "PRICE", y = "RM", data = d)

# %%
a = df[['B', 'TAX', 'PRICE']]
fig, ax = plt.subplots(figsize=(11, 9))
sb.heatmap(a)
plt.show()

# %% [markdown]
# PART B

# %%
unemployment = pd.read_excel('https://github.com/dayanandv/Data-Science/raw/main/dataset/unemployment.xlsx')
plt.figure(figsize=(16,5))
sb.stripplot(x = unemployment.Age, palette="Set1", y = unemployment.Unemployed , jitter=0.3, hue= unemployment.Gender)

# %%
plt.figure(figsize=(15,12))
sb.boxplot(x = unemployment['Age'], y = unemployment['Unemployed']);

# %%
df7 = pd.read_excel("https://github.com/dayanandv/Data-Science/raw/main/dataset/unemployment.xlsx")
explodee = (0.1, 0.1)
label = 'Men','Women'
mw = []
i = (df7["Gender"] == 'Men').count()
mw.append(i)
i = (df7["Gender"] == 'Women').count()
mw.append(i)
plt.pie(mw, labels = label, autopct = '%1.1f%%', startangle = 90, shadow = True, explode = explodee)
plt.show()
